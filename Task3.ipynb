# %%
import urllib.request as req 
import json
import csv
import pandas as pd
import re

# %%
url = "https://www.kkbox.com/hk/tc/song/P_DOOVEaadNrj8lR1t"
with req.urlopen(url) as response:
    data = response.read().decode("utf-8")
    
#解析原始碼
import bs4
home = bs4.BeautifulSoup(data,"html.parser") #解析
print(home.title.string) #嘗試抓網站名稱
# Out:
# 2 MINUS 1 - Bonus Track-歌詞-SEVENTEEN (세븐틴)-KKBOX

# %%
print(home)
# Out:
# <!DOCTYPE html>
#
# <html lang="zh-hant-hk" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <link crossorigin="" href="https://i.kfs.io" rel="preconnect"/>
# <link crossorigin="" href="https://cdn.rollbar.com" rel="preconnect"/>
# <link crossorigin="" href="https://api-portal.kkbox.com.tw" rel="preconnect"/>
# <meta content="setting for rollbar" data-env="luna-production" data-token="b1104e5c43af4d4ca8bbb1ff1d724382" name="rollbar-setting"/>
# ...

# %%
songs = []
for title in titles:
    print(title.a.string) #第一頁所有歌印出
    songs.append(title.a.string)
songs

# %%
text= home
pattern = r'Two minus one'
matches=re.findall(pattern,text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 text= home
#       2 pattern = r'Two minus one'
# ----> 3 matches=re.findall(pattern,text)
#
# File ~\anaconda3\Lib\re\__init__.py:216, in findall(pattern, string, flags)
#     208 def findall(pattern, string, flags=0):
#     209     """Return a list of all non-overlapping matches in the string.
#     210
#     211     If one or more capturing groups are present in the pattern, return
#    (...)
#     214
#     215     Empty matches are included in the result."""
# --> 216     return _compile(pattern, flags).findall(string)
#
# TypeError: expected string or bytes-like object, got 'BeautifulSoup'

# %%
print(matches)
# Out:
# []
