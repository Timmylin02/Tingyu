# %%
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('WebF5.csv')

data
# Out:
#            日期    新臺幣發行數額-鈔券    新臺幣發行數額-硬幣   黃金準備-重量(公克)  黃金準備-價格(新臺幣元/公克)  \
# 0   090/03/31  6.613020e+11  5.346815e+10  4.102373e+08             273.0
# 1   090/06/30  6.409600e+11  5.337736e+10  4.102373e+08             298.0
# 2   090/09/30  6.403260e+11  5.337736e+10  4.102373e+08             322.0
# 3   090/12/31  6.394590e+11  5.345293e+10  4.102373e+08             312.0
# 4   091/03/31  6.720950e+11  5.377101e+10  4.102373e+08             340.0
# ..        ...           ...           ...           ...               ...
# 85  111/06/30  2.948470e+12  1.269760e+11  4.102373e+08            1725.0
# 86  111/09/30  2.991320e+12  1.281980e+11  4.102373e+08            1709.0
# 87  111/12/31  3.225760e+12  1.310700e+11  4.102373e+08            1782.0
# 88  112/03/31  3.219570e+12  1.311580e+11  4.102373e+08            1924.0
# 89  112/06/30  3.184499e+12  1.320865e+11  4.102373e+08            1895.0
#
#     黃金準備-金額(新臺幣元)     外匯美金準備-美元  外匯美金準備-匯率(新臺幣元/美元)     金額(新臺幣/元)
# ...

# %%
#外匯美金準備-美元 數據整理
column_USD_COIN = df['外匯美金準備-美元']
column_USD_COIN1 = column_NTD_COIN.dropna()

column_USD_COIN1.head(20)
# Out:
# 0     5.346815e+10
# 1     5.337736e+10
# 2     5.337736e+10
# 3     5.345293e+10
# 4     5.377101e+10
# 5     5.198575e+10
# 6     4.904394e+10
# 7     4.931998e+10
# 8     4.992728e+10
# 9     5.051820e+10
# 10    5.119726e+10
# 11    5.283766e+10
# 12    5.359440e+10
# 13    5.238943e+10
# 14    5.187676e+10
# 15    5.339687e+10
# 16    5.463309e+10
# 17    5.545450e+10
# 18    5.637307e+10
# 19    5.759602e+10
# Name: 新臺幣發行數額-硬幣, dtype: float64

# %%
column_GOLD_PRICE = df['外匯美金準備-匯率(新臺幣元/美元)']
column_GOLD_PRICE1 = column_GOLD_PRICE.dropna()

column_GOLD_PRICE1
# Out:
# 0     33.00
# 1     34.00
# 2     35.00
# 3     35.00
# 4     35.00
#       ...
# 85    30.00
# 86    32.00
# 87    31.00
# 88    30.00
# 89    31.11
# Name: 外匯美金準備-匯率(新臺幣元/美元), Length: 90, dtype: float64

# %%
#圖表設定(時間和黃金的關係)

#XY設定
X=df['日期']
Y=df['黃金準備-金額(新臺幣元)']

#圖表外觀設定
fig, ax = plt.subplots(figsize=(10, 6))
x_ticks = np.arange(0, len(X), 1000)
ax.tick_params(axis='x', rotation=90)


ax.scatter(X, Y)
fig.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24844\1819269017.py:16: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
#圖表設定(時間和外匯美金的關係)

X=df['日期']
Y=df['外匯美金準備-美元']

fig, ax = plt.subplots(figsize=(10, 6))
x_ticks = np.arange(0, len(X), 1000)
ax.tick_params(axis='x', rotation=90)

ax.scatter(X, Y)
fig.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24844\2608694033.py:12: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
#圖表設定(外匯美金和黃金的關係)

X=df['外匯美金準備-美元']
Y=df['黃金準備-金額(新臺幣元)']

fig, ax = plt.subplots(figsize=(10, 6))

ax.scatter(X, Y)
fig.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24844\3904909297.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
